# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from google.colab import drive

# Import pandas and read the charity_data.csv from the provided cloud URL.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(['EIN', 'SPECIAL_CONSIDERATIONS'], axis=1)
application_df.head()
# Out:
#                                        NAME APPLICATION_TYPE  \
# 0              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT  ASK_AMT  IS_SUCCESSFUL
# 0              0     5000              1
# 1         1-9999   108590              1
# 2              0     5000              0
# 3    10000-24999     6692              1
# 4  100000-499999   142590              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# NAME                19568
# APPLICATION_TYPE       17
# AFFILIATION             6
# CLASSIFICATION         71
# USE_CASE                5
# ORGANIZATION            4
# STATUS                  2
# INCOME_AMT              9
# ASK_AMT              8747
# IS_SUCCESSFUL           2
# dtype: int64

# %%
# 'NAME' value counts
names = application_df['NAME'].value_counts()
names
# Out:
# NAME
# PARENT BOOSTER USA INC                                     1260
# TOPS CLUB INC                                               765
# UNITED STATES BOWLING CONGRESS INC                          700
# WASHINGTON STATE UNIVERSITY                                 492
# AMATEUR ATHLETIC UNION OF THE UNITED STATES INC             408
#                                                            ...
# NEW MEXICO ASSOCIATION OF INDEPENDENT SCHOOLS INC             1
# DC COUNCIL MINISTRIES                                         1
# CHRISTIANS AGAINST GUN VIOLENCE ENDAGERING OUR CHILDREN       1
# MCKINNEY CITIZENS FIRE ACADEMY ALUMNI ASSOCIATION             1
# AIESEC ALUMNI IBEROAMERICA CORP                               1
# Name: count, Length: 19568, dtype: int64

# %%
#  'NAME' value counts
names_to_replace = names[names < 10].index

# Replace in dataframe
for name in names_to_replace:
    application_df['NAME'] = application_df['NAME'].replace(name,"Other")

# Check to make sure binning was successful
application_df['NAME'].value_counts()
# Out:
# NAME
# Other                                      21022
# PARENT BOOSTER USA INC                      1260
# TOPS CLUB INC                                765
# UNITED STATES BOWLING CONGRESS INC           700
# WASHINGTON STATE UNIVERSITY                  492
#                                            ...
# CASCADE 4-H FOUNDATION                        10
# STEVES CLUB NATIONAL PROGRAM                  10
# GENERAL FEDERATION OF WOMENS CLUB             10
# NATIONAL ASSOCIATION OF LETTER CARRIERS       10
# UNION OF CALIFORNIA STATE WORKERS             10
# Name: count, Length: 223, dtype: int64

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
value_counts = application_df.value_counts('APPLICATION_TYPE')
print(value_counts)
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T15        2
# T29        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = value_counts[value_counts < 528].index

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
class_value_counts = application_df['CLASSIFICATION'].value_counts()
print(class_value_counts)
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C1248        1
# C6100        1
# C1820        1
# C1900        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_counts = class_value_counts[class_value_counts >1]
print(class_counts)
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C6000       15
# C1800       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1237        9
# C1235        9
# C7210        7
# C1720        6
# C2400        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1256        2
# C1246        2
# C1234        2
# C1267        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = class_value_counts[class_value_counts < 1883].index

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_dummies = pd.get_dummies(application_df)
application_dummies.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  NAME_ACE MENTOR PROGRAM OF AMERICA INC  \
# 0       1     5000              1                                   False
# 1       1   108590              1                                   False
# 2       1     5000              0                                   False
# 3       1     6692              1                                   False
# 4       1   142590              1                                   False
#
#    NAME_AIR FORCE ASSOCIATION  NAME_ALABAMA FEDERATION OF WOMENS CLUBS  \
# 0                       False                                    False
# 1                       False                                    False
# 2                       False                                    False
# 3                       False                                    False
# 4                       False                                    False
#
#    NAME_ALABAMA TREASURE FOREST ASSOCIATION  NAME_ALPHA PHI SIGMA  \
# 0                                     False                 False
# 1                                     False                 False
# 2                                     False                 False
# 3                                     False                 False
# 4                                     False                 False
#
#    NAME_ALPHA PHI SIGMA INC  NAME_ALTRUSA INTERNATIONAL FOUNDATION INC  ...  \
# 0                     False                                      False  ...
# 1                     False                                      False  ...
# 2                     False                                      False  ...
# 3                     False                                      False  ...
# 4                     False                                      False  ...
#
#    ORGANIZATION_Trust  INCOME_AMT_0  INCOME_AMT_1-9999  \
# 0               False          True              False
# 1               False         False               True
# 2               False          True              False
# 3                True         False              False
# 4                True         False              False
#
#    INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  INCOME_AMT_10M-50M  \
# 0                   False                     False               False
# 1                   False                     False               False
# 2                   False                     False               False
# 3                    True                     False               False
# 4                   False                      True               False
#
#    INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  INCOME_AMT_50M+  \
# 0             False                   False            False
# 1             False                   False            False
# 2             False                   False            False
# 3             False                   False            False
# 4             False                   False            False
#
#    INCOME_AMT_5M-10M
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
#
# [5 rows x 265 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = application_dummies['IS_SUCCESSFUL']
X = application_dummies.drop(columns=['IS_SUCCESSFUL'])

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Check number of features
input_features = X.shape[1]
print(input_features)
# Out:
# 264

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

nn_optimization_3 = tf.keras.models.Sequential([
                                 tf.keras.Input(shape=(input_features,)),
                                 tf.keras.layers.Dense(20, activation='tanh'),
                                 tf.keras.layers.Dense(16, activation='tanh'),
                                 tf.keras.layers.Dense(11, activation='tanh'),
                                 tf.keras.layers.Dense(5, activation='tanh'),
                                 tf.keras.layers.Dense(1, activation='sigmoid')
                                 ])


# Check the structure of the model
nn_optimization_3.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_5 (Dense)                 │ (None, 20)             │         5,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 16)             │           336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 11)             │           187 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 5)              │            60 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,889 (23.00 KB)
#  Trainable params: 5,889 (23.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
nn_optimization_3.compile(optimizer='adam',
           loss='binary_crossentropy',
           metrics=['accuracy'])

# %%
# Train the model
history = nn_optimization_3.fit(
    X_train_scaled, y_train,
    epochs=80,
    batch_size=64,
    validation_split=0.2
    )
# Out:
# Epoch 1/80
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6997 - loss: 0.5709 - val_accuracy: 0.7843 - val_loss: 0.4596
# Epoch 2/80
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7749 - loss: 0.4649 - val_accuracy: 0.7870 - val_loss: 0.4476
# Epoch 3/80
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7821 - loss: 0.4487 - val_accuracy: 0.7878 - val_loss: 0.4451
# Epoch 4/80
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7818 - loss: 0.4503 - val_accuracy: 0.7881 - val_loss: 0.4430
# Epoch 5/80
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7843 - loss: 0.4447 - val_accuracy: 0.7848 - val_loss: 0.4429
# Epoch 6/80
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7870 - loss: 0.4387 - val_accuracy: 0.7916 - val_loss: 0.4413
# Epoch 7/80
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7883 - loss: 0.4346 - val_accuracy: 0.7874 - val_loss: 0.4424
# Epoch 8/80
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7931 - loss: 0.4321 - val_accuracy: 0.7837 - val_loss: 0.4437
# Epoch 9/80
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.